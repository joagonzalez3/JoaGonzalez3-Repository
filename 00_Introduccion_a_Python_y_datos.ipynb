# %% [markdown]
# **Laboratorio de Métodos Cuantitativos Aplicados a la Gestión**
#
# ---
#
# # **Clase 00 - 🐍 Introducción a Python y análisis de datos**

# %% [markdown]
# ## Objetivo de la Notebook 🎯
#
# Esta notebook cubre los **fundamentos del lenguaje Python**: lo mínimo que hay que manejar para que
# todo lo que viene después —tablas, gráficos, modelos— tenga sentido.
#
# **Lo que vamos a ver:**
# * 🔢 Operaciones matemáticas y variables
# * 💬 Cómo mostrar números de forma legible: decimales, miles, porcentajes
# * 📦 Tipos de datos: `int`, `float`, `str`, `bool`, `list`, `tuple`, `dict`
# * ⚖️ Cuándo conviene una tupla y cuándo un diccionario
# * 🔀 Control de flujo: `if/elif/else`, ciclos `for`
# * 🛠️ Funciones
#
# > 📌 **El análisis de datos con pandas (DataFrames, filtrado, agrupación y visualizaciones) se
# > trabaja en la clase 01.** Acá construimos la base sobre la que se apoya.

# %% [markdown]
# ## ⚙️ Instalación de librerías
#
# Ejecutá esta celda antes de comenzar. Instala todas las librerías necesarias para correr el notebook.

# %%
# Instalación de librerías necesarias (correr solo una vez al iniciar el entorno)
# !pip install numpy pandas matplotlib seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# [notice] A new release of pip is available: 25.3 -> 26.2.1
# [notice] To update, run: C:\Python313\python.exe -m pip install --upgrade pip
# ...

# %% [markdown]
# ---
# # 📓 Cómo funciona un notebook
#
# Antes de escribir una línea de código, hay que entender **dónde** la estamos escribiendo.
#
# Un notebook es una lista de **celdas**, y hay dos tipos:
#
# | Tipo | Qué tiene | Cómo se ve |
# |---|---|---|
# | **Código** | Python que se ejecuta | Fondo gris, con un ▶ a la izquierda |
# | **Texto** (Markdown) | Explicaciones como esta | Texto formateado |

# %% [markdown]
# ### ⚠️ El orden de ejecución: la causa del 90% de los problemas
#
# Esto es **lo más importante de toda la clase**, y es lo que más confunde al empezar.
#
# Un notebook **no se ejecuta de arriba a abajo automáticamente**. Se ejecuta en el orden en que
# **vos apretás** las celdas. Python recuerda todo lo que ejecutaste, sin importar dónde estaba escrito.
#
#
# > 🚨 **El síntoma típico:** "a mí me anda y a vos no". Casi siempre es porque uno ejecutó las celdas
# > en distinto orden. Si algo se pone raro: **Entorno de ejecución → Reiniciar y ejecutar todo**.
# > Eso corre todo limpio, de arriba a abajo, y es la prueba de que el notebook realmente funciona.

# %% [markdown]
# > 📌 **Otra cosa que hay que saber de Colab:** todo lo que hagas vive en una máquina virtual que
# > **se apaga sola** después de un rato de inactividad. Cuando eso pasa, se pierden las variables y
# > los archivos que hayas subido — pero **no** el código, que queda guardado.
# >
# > Si volvés a un notebook y todo "dejó de andar", casi siempre alcanza con volver a ejecutar
# > desde arriba.

# %% [markdown]
# # 🐍 Introducción al lenguaje de programación Python
#
# Vamos a cubrir algunos conceptos básicos del lenguaje de programación Python, incluyendo variables y tipos de datos, indexación y segmentación, flujo de control y funciones. Esta versión es solo un esqueleto.

# %% [markdown]
# ---

# %% [markdown]
# ## ➕ Operaciones matemáticas básicas
#
# Primero, usemos Python como calculadora para ver su comportamiento. A menudo, las celdas solo muestran una salida, aunque se ejecutan todas las líneas de código. Si desea generar varias a la vez, puede ser útil usar el comando print, como se muestra al final. Python imprimirá explícitamente todas las salidas de cualquier comando print (incluso si hay varias).
#
# Al agregar el carácter '#', le indica a Python que ignore los siguientes caracteres en la misma línea. Esto se llama crear un **comentario** y puede ser muy útil para explicar su código a otros.

# %%
1+1 # Python va a ignorar todo después del '#'
# Out:
# 2

# %%
333/10
# Out:
# 33.3

# %%
1+1/2 # Python sigue el orden de operaciones
# Out:
# 1.5

# %%
3 ** 3 # Python usa '**' en vez de '^' para exponentes
# Out:
# 27

# %%
# Para practicar: calcule la raíz cuadrada de 356 pregunte a una IA como es la forma correcta de escribirlo en Python

# %% [markdown]
# ---

# %% [markdown]
# ## 📌 Variables
#
# Una característica muy útil de cualquier lenguaje de programación es la posibilidad de asignar un nombre fijo a las variables. Simplemente use la fórmula:
#
# ```
# nombre_variable = valor_deseado
# ```
#
# **Nota:** Los nombres de las variables *NO DEBEN comenzar con un número ni incluir guiones ni espacios* .
#
# Después de esto, cada vez que escriba el nombre de la variable, Python hará referencia al valor asignado. Si alguna vez usa el mismo nombre de variable, el valor se sobrescribirá.
#
# Python considera todos los tipos de texto como algún tipo de variable o comando. Si alguna vez desea crear o hacer referencia a texto real, debe estar entre comillas. Esto se denomina cadena en Python. Si desea que Python ignore el texto por completo, use '#' para indicar un comentario.

# %%
a = 1 # Todas las celdas futuras ahora refieren a a como 1
b = 2

a+b
# Out:
# 3

# %%
a, b = 1, 2 # Asigna las variables anteriores de la misma manera pero en una línea
a+b
# Out:
# 3

# %%
a = z = 1 # Otra forma de asignar el mismo valor a múltiples variables

z
# Out:
# 1

# %% [markdown]
# Todas las operaciones matemáticas funcionan igual con variables

# %%
a*5
# Out:
# 5

# %%
b ** 5
# Out:
# 32

# %%
a = 500 # si vuelven a usar el mismo nombre de variable, sobreescriben el valor anterior

a+b
# Out:
# 502

# %%
# Por defecto, Python solo muestra la última línea de salida de una celda

a*b # Esta línea se ejecutará en Python, pero como la siguiente línea genera una salida y viene después, solo se mostrará su salida.

a+b
# Out:
# 502

# %%
print(a*b, a+b) # usando print y una coma separando items va a mostrar todo
# Out:
# 1000 502

# %%
a = "you can't add strings to numbers" # Si deseas generar texto para que Python lo almacene en la memoria, utilizá comillas alrededor del texto para crear una cadena (str para abreviar)
print(a)
# Out:
# you can't add strings to numbers

# %%
b = ", but you can add strings together!"

a+b # Incluso podéss concatenar texto, fijense aca imprimimos sin print
# Out:
# "you can't add strings to numbers, but you can add strings together!"

# %%
# Para practicar: Asigna el número 82 a la variable llamada meaning_of_life, luego encontrá el resto de la división de meaning of life por 10

# %% [markdown]
# ### Principales funciones para imprimir en pantalla
#
# | Función | Uso | Ejemplo |
# |---|---|---|
# | `print()` | La más común, imprime en stdout | `print("hola")` |
# | `display()` | IPython/Jupyter, muestra objetos con formato | `display(df)` |
# | `repr()` | Devuelve representación del objeto como string | `print(repr(df))` |
# | `str()` | Convierte a string legible | `print(str(42))` |

# %% [markdown]
# ---

# %% [markdown]
# ## 🗂️ Data Types
#
# Existen _muchos_ tipos de datos en Python. Para comprobar el tipo de un objeto, usa la función `type()`.
#
# Los más comunes que vas a encontrar son:
#
# * entero (p. ej., 100)
# * flotante (p. ej., 100.0)
# * cadena (p. ej., '¡Hola mundo!')
# * booleano (p. ej., verdadero)
# * lista (p. ej., ['uno', 'dos', 'tres'])
# * tuplas (p. ej., ('uno', 'dos', 'tres'))
# * diccionario (p. ej., {'mamífero': 'ornitorrinco', 'pez': 'anguila'})
# * array de NumPy
# * Pandas Series (en futuros notebooks)
# * Pandas DataFrame (en futuros notebooks)

# %% [markdown]
# ---

# %% [markdown]
# ### 🔢 Integers y Floats
#
# Estos son los types más comunes que van a encontrar. **Integers son numeros enteros** y **floats tienen decimales**.

# %%
a = 5

b = 5.0

print(type(a), type(b))
# Out:
# <class 'int'> <class 'float'>

# %%
int(b) # convierte b a integer, noten que si no lo asignamos de nuevo a b ejecutando 'b=int(b)', b no va a cambiar
# Out:
# 5

# %%
b = int(b)

b
# Out:
# 5

# %% [markdown]
# ---

# %% [markdown]
# ### 🔤 Strings
#
# Strings son como pedacitos de texto. Siempre están entre comillas, simples o dobles. Podés convertir números a str también. En ese caso van a pasar a tener todas las propiedades del str.

# %% [markdown]
# ### 💬 Mostrar números de forma legible
#
# Un resultado como `1234567.891` no se le muestra a nadie así. En un informe, en una reunión o en un
# tablero, **el número se presenta**. Dentro de un f-string, después de los dos puntos `:` se indica
# **cómo** formatear:
#
# | Formato | Qué hace | Ejemplo |
# |---|---|---|
# | `:.2f` | 2 decimales | `1234567.89` |
# | `:,.0f` | Separador de miles, sin decimales | `1,234,568` |
# | `:,.2f` | Miles **y** 2 decimales | `1,234,567.89` |
# | `:.1%` | Como porcentaje | `12.3%` |
# | `:+,.2f` | Fuerza el signo (útil para variaciones) | `+1,234,567.89` |
# | `:>10` | Alineado a la derecha en 10 espacios | `      hola` |
#
# Lo vas a usar en **toda** la materia para que las salidas se lean.

# %%
facturacion = 1234567.891
margen = 0.1234
variacion = -0.0876

print("Sin formato :", facturacion)
print(f"2 decimales : {facturacion:.2f}")
print(f"Con miles   : {facturacion:,.0f}")
print(f"Completo    : $ {facturacion:,.2f}")
print(f"Porcentaje  : {margen:.1%}")
print(f"Variación   : {variacion:+.1%}")   # el + siempre muestra el signo

# Alinear en columnas: muy útil para que una tabla impresa se lea
print()
productos = ["Notebook", "Mouse", "Monitor"]
precios = [890000.5, 12500.75, 340000]
for nombre, precio in zip(productos, precios):
    print(f"{nombre:<12} $ {precio:>12,.2f}")
# Out:
# Sin formato : 1234567.891
# 2 decimales : 1234567.89
# Con miles   : 1,234,568
# Completo    : $ 1,234,567.89
# Porcentaje  : 12.3%
# Variación   : -8.8%
#
# Notebook     $   890,000.50
# Mouse        $    12,500.75
# Monitor      $   340,000.00

# %% [markdown]
# #### 🎭 Formatear **no** es redondear
#
# Esta es la distinción que más problemas trae cuando el número después se usa para calcular:
#
# | | Qué hace | El valor guardado |
# |---|---|---|
# | `f"{x:.2f}"` | Cambia **cómo se ve** | Queda **intacto** |
# | `round(x, 2)` | Cambia **el valor** | Queda **redondeado** |
#
# Regla práctica: **calculá con todos los decimales y redondeá solo al final, para mostrar.**
# Si redondeás en cada paso intermedio, los errores se van sumando y el total no cierra.

# %%
precio_unitario = 1234.5678

# Formatear: solo cambia la presentación
print(f"Formateado : {precio_unitario:.2f}   ← se ve con 2 decimales")
print("El valor sigue siendo:", precio_unitario)

# Redondear: cambia el número de verdad
precio_redondeado = round(precio_unitario, 2)
print("\nRedondeado :", precio_redondeado, "  ← el valor cambió")

# Por qué importa: 1000 unidades facturadas
print("\nCon el valor completo  : $", f"{precio_unitario * 1000:,.2f}")
print("Con el valor redondeado: $", f"{precio_redondeado * 1000:,.2f}")
print("Diferencia             : $", f"{(precio_unitario - precio_redondeado) * 1000:,.2f}")
# Out:
# Formateado : 1234.57   ← se ve con 2 decimales
# El valor sigue siendo: 1234.5678
#
# Redondeado : 1234.57   ← el valor cambió
#
# Con el valor completo  : $ 1,234,567.80
# Con el valor redondeado: $ 1,234,570.00
# Diferencia             : $ -2.20

# %% [markdown]
# ---

# %% [markdown]
# ### ✅ Booleans
#
# **Los booleans** toman dos valores posibles (prestá atención al uso de mayúsculas):
# * `True`
# * `False`
#
# Estos se pueden usar para evaluar condiciones, por ejemplo, al comparar el valor de diferentes variables. Específicamente, podés crear condiciones usando uno de los siguientes operadores de comparación:
# * `==` es igual (recuerde que el operador `=` representa una asignación en Python)
# * `!=` no es igual a
# * `>=` mayor o igual a
# * `<=` menor o igual a
# * `is` y `is not` también producen valores booleanos; sin embargo, requieren coincidencias de identidad exactas, a diferencia de `==` y `!=`.
#
# Tené en cuenta que muchas otras funciones y sintaxis devuelven valores booleanos. Por ejemplo, existe la función ``` isinstance(x, var_type) ``` que devuelve el valor booleano correspondiente si la variable x es equivalente al tipo especificado. Verificá siempre las salidas de las funciones para gestionar sus tipos de datos eficazmente.
#
# "True" también corresponde al valor "1", mientras que "False" corresponde a "0".

# %%
e = 5

f = 5.00

print(e>f, e==f,  e>=f, e!=f)
# Out:
# False True True False

# %%
print(e is f) # Tené en cuenta que, dado que e no es exactamente lo mismo que f, "es" devuelve False.
# Out:
# False

# %%
c = "cualquier texto entre comillas simples o dobles es string"
d = 'cualquier texto entre comillas simples o dobles es string'

print(c == d) # Como se mencionó, aunque el segundo usa comillas simples, es equivalente en Python.
# Out:
# True

# %%
print(isinstance(c, str)) # Muchas funciones pueden devolver valores booleanos como esta, que verifica si la variable c es string (usá la forma corta str)
# Out:
# True

# %%
print(True == 1, False == 0) # El valor booleano de Verdadero es igual a 1; el valor booleano de Falso es igual a 0.
# Esto será útil para variables categóricas.
# Out:
# True True

# %%
# Python solo reconoce False y True como valores booleanos, FALSE y false (TRUE y true) se consideran posibles nombres de variables.
print(type(False), type(True))
# Out:
# <class 'bool'> <class 'bool'>

# %%
# print(type(FALSE)) # solo False funciona como boolean, sino, Python piensa que es una variable

# %% [markdown]
# Podemos combinar condiciones con:
# *    `and` (deben cumplirse todas)
# *    `or` (al menos una debe cumplirse)
# *    `not` (invierte el resultado)

# %%
p = 1
q = 2

p > q and p < q # ya que ambos deben satisfacerse, pero cada uno es mutuamente excluyente en este caso, esto debe ser False
# Out:
# False

# %%
p > q or p < q # como uno se cumple, es True
# Out:
# True

# %%
not (p == q) # la expersión entre paréntesis es False pero 'not' los da vuelta
# Out:
# True

# %%
# Para practicar: Introducí una variable llamada edad y asígnale un valor a tu elección. Escribí una condición que compruebe si el cuadrado de la edad es menor que 625.

# %% [markdown]
# ---

# %% [markdown]
# ### 📋 Listas: indexación y rebanado
#
# Una **lista** es un contenedor **ordenado** de elementos. Los elementos pueden ser de cualquier tipo
# (textos, números, otras listas, tuplas...). Se crean poniendo el contenido entre **corchetes**,
# separado por comas. Una lista vacía es simplemente `[]`.
#
# Cada elemento tiene una posición única llamada **índice**. En Python **se empieza a contar desde 0**:
# el primer elemento es el `0`, el segundo el `1`, y así.
#
# Vamos a trabajar con el **stock de un depósito**, que es exactamente la clase de dato que después
# vamos a manejar con pandas.

# %%
lista_vacia = []   # Inicializar listas vacías sirve mucho para ir llenándolas dentro de un ciclo

type(lista_vacia)
# Out:
# list

# %%
# Una lista se crea poniendo los elementos entre corchetes, separados por comas
stock_deposito = ['monitores', 'teclados', 'notebooks', 'impresoras', 'sillas']

stock_deposito[0]   # el primer elemento: el que está en el índice 0
# Out:
# 'monitores'

# %%
stock_deposito[-1]  # con números negativos se cuenta desde el final: -1 es el último, -2 el anteúltimo
# Out:
# 'sillas'

# %%
# Se puede reemplazar un elemento por su índice. Cambiamos el proveedor del segundo artículo:
stock_deposito[1] = 'auriculares'

print(stock_deposito)
# Out:
# ['monitores', 'auriculares', 'notebooks', 'impresoras', 'sillas']

# %%
# Si un artículo se discontinuó, lo sacamos del inventario con del
del stock_deposito[2]

print(stock_deposito)
# Out:
# ['monitores', 'auriculares', 'impresoras', 'sillas']

# %%
# Para practicar: armá una lista con los datos de un cliente. Inventá una persona
# con nombre, edad, código postal y correo, y guardá todo en una sola lista.

# Datos del cliente
cliente = ["Carlos López", 34, "1425", "carlos.lopez@gmail.com"]

# Saludo
print(f'Hola {cliente[0]}. Un gusto. Veo que tenés {cliente[1]} años')
# Out:
# Hola Carlos López. Un gusto. Veo que tenés 34 años

# %%
print(f'Hola {cliente[0]}. Un gusto. Veo que tenés {cliente[1]} años')
# Out:
# Hola Carlos López. Un gusto. Veo que tenés 34 años

# %% [markdown]
# El **rebanado** (*slicing*) es la forma habitual de seleccionar varios elementos a la vez. Se usa el
# índice más `:`, que se lee como _"hasta, pero sin incluir"_.
#
# Por ejemplo, `2:10` significa _desde el elemento con índice 2 hasta el 10, sin incluir el 10_.
# Si no ponés inicio, Python arranca del principio; si no ponés final, va hasta el último.

# %%
stock_deposito[0:2]   # del primer elemento (índice 0) hasta el tercero, sin incluirlo
# Out:
# ['monitores', 'auriculares']

# %%
stock_deposito[2:]    # del tercer elemento hasta el final. Si fuera [:2], iría del principio al índice 2 sin incluirlo
# Out:
# ['impresoras', 'sillas']

# %%
compra_pendiente = ['tablets']

stock_proyectado = stock_deposito + compra_pendiente

stock_proyectado   # sumar dos listas las combina: el stock de hoy más lo que está por llegar
# Out:
# ['monitores', 'auriculares', 'impresoras', 'sillas', 'tablets']

# %%
stock_invertido = stock_deposito.copy()
stock_invertido.reverse()
print(stock_invertido)
# Out:
# ['sillas', 'impresoras', 'auriculares', 'monitores']

# %%
# Para practicar:
# Recién vimos .reverse(). Las listas tienen muchos métodos más. Buscá y aplicá uno para imprimir
# todos los elementos de stock_deposito en orden descendente (de la Z a la A).

# %%
stock_deposito.append('escritorios')  # .append() agrega un elemento al final: llegó mercadería nueva

# Cada tipo de dato tiene sus propios métodos. Vale la pena conocerlos: simplifican muchísimo el código.
print(stock_deposito)
# Out:
# ['monitores', 'auriculares', 'impresoras', 'sillas', 'escritorios']

# %%
stock_sucursal = stock_deposito   # queremos una lista nueva, basada en la anterior

stock_sucursal[1] = 'proyectores'  # cambiamos un elemento en la sucursal

print(stock_sucursal, stock_deposito)  # ¿por qué cambió TAMBIÉN el depósito, si tocamos la sucursal?
# Out:
# ['monitores', 'proyectores', 'impresoras', 'sillas', 'escritorios'] ['monitores', 'proyectores', 'impresoras', 'sillas', 'escritorios']

# %%
# Porque los dos nombres apuntan a la MISMA lista. Para tener una copia independiente, usá .copy()
stock_sucursal = stock_deposito.copy()

stock_sucursal[2] = 'cargadores'

print(stock_sucursal, stock_deposito)   # ahora sí: cada una por su lado
# Out:
# ['monitores', 'proyectores', 'cargadores', 'sillas', 'escritorios'] ['monitores', 'proyectores', 'impresoras', 'sillas', 'escritorios']

# %% [markdown]
# ---

# %% [markdown]
# #### ⚙️ Métodos de las listas
#
# Las **listas** tienen muchos métodos útiles. Podés ver los más comunes acá:
# https://docs.python.org/3/tutorial/datastructures.html
#
# Ejemplos:

# %% [markdown]
# #### 📊 Resumir una lista sin recorrerla
#
# Python trae funciones que responden preguntas sobre una lista entera de una sola vez.
# **Son la versión mínima de lo que después haremos con pandas.**
#
# | Función | Qué devuelve |
# |---|---|
# | `len(lista)` | Cuántos elementos tiene |
# | `sum(lista)` | La suma de todos |
# | `max(lista)` / `min(lista)` | El mayor / el menor |
# | `sorted(lista)` | Una **copia** ordenada |
# | `lista.sort()` | Ordena **la lista original** y devuelve `None` |

# %%
ventas = [420, 145, 610, 480, 190, 130]

print("Cantidad de productos:", len(ventas))
print("Total vendido        :", sum(ventas))
print("El que más vendió    :", max(ventas))
print("El que menos vendió  :", min(ventas))
print("Promedio             :", sum(ventas) / len(ventas))
# Out:
# Cantidad de productos: 6
# Total vendido        : 1975
# El que más vendió    : 610
# El que menos vendió  : 130
# Promedio             : 329.1666666666667

# %%
# sorted() vs .sort() — una diferencia que confunde mucho
original = [420, 145, 610]

copia_ordenada = sorted(original)          # devuelve una lista NUEVA
print("sorted() devuelve:", copia_ordenada)
print("y el original queda intacto:", original)

resultado = original.sort()                 # ordena EN EL LUGAR
print("\n.sort() devuelve:", resultado, "  ← ¡None! no devuelve la lista")
print("pero el original cambió:", original)
# Out:
# sorted() devuelve: [145, 420, 610]
# y el original queda intacto: [420, 145, 610]
#
# .sort() devuelve: None   ← ¡None! no devuelve la lista
# pero el original cambió: [145, 420, 610]

# %% [markdown]
# > ⚠️ **El error clásico:** escribir `lista = lista.sort()`. Como `.sort()` devuelve `None`,
# > tu variable queda valiendo `None` y todo lo que sigue falla. Si querés una copia ordenada, usá
# > `sorted()`.

# %% [markdown]
# ---

# %% [markdown]
# ### 🔒 Tuplas
#
# Una **tupla** es un contenedor ordenado, igual que una lista, con **una diferencia fundamental:
# no se puede modificar**. Una vez creada, no le podés cambiar, agregar ni borrar elementos.
#
# En lugar de corchetes, se escriben entre **paréntesis**. Si tenés un solo elemento, alcanza con
# agregarle una coma para que sea una tupla.
#
# Esa rigidez no es un defecto: es **una garantía**. Cuando algo no debería cambiar nunca —el
# encabezado de un reporte, las coordenadas de una sucursal, los datos de una operación ya cerrada—
# guardarlo en una tupla evita que se modifique por accidente tres pantallas más abajo.

# %%
encabezado_reporte = ('Sucursal', 'Producto', 'Unidades')

type(encabezado_reporte)
# Out:
# tuple

# %%
encabezado_reporte[2]   # la indexación funciona igual que en las listas
# Out:
# 'Unidades'

# %%
# encabezado_reporte[2] = 'Importe'  # ← si lo descomentás, falla: las tuplas no se pueden modificar

# %%
# Se puede "desarmar" una tupla asignando cada elemento a una variable distinta
columna_1, columna_2, columna_3 = encabezado_reporte
print('El reporte tiene las columnas', columna_1, ',', columna_2, 'y', columna_3)
# Out:
# El reporte tiene las columnas Sucursal , Producto y Unidades

# %%
# del encabezado_reporte[2]   # ← tampoco se pueden borrar elementos

# %%
encabezado_lista = list(encabezado_reporte)  # una tupla NO se puede cambiar, pero sí convertir en lista

encabezado_lista   # fijate los corchetes: ahora es una lista y se puede modificar
# Out:
# ['Sucursal', 'Producto', 'Unidades']

# %%
columna_extra = 'Importe',   # con la coma alcanza para que sea una tupla de un solo elemento
encabezado_reporte + columna_extra   # sumar tuplas las combina en una nueva
# Out:
# ('Sucursal', 'Producto', 'Unidades', 'Importe')

# %%
# Para practicar: desarmá la siguiente tupla en tres variables llamadas
# centro_1, centro_2 y centro_3

centros_de_costo = ('Ventas', 'Marketing', 'Logística')

# %% [markdown]
# ---

# %% [markdown]
# ### 📦 Otros tipos de datos
#
# Como dijimos, existen muchos otros tipos de datos. Algunos aparecen recién cuando cargás una
# librería específica. A medida que sumes librerías nuevas, consultá su documentación para conocer
# los tipos de datos que traen y cómo aprovecharlos.

# %% [markdown]
# ---

# %% [markdown]
# ## 🔀 Control de flujo
#
# Para manejar el **control de flujo** de un programa necesitamos dos estructuras básicas:
# **condiciones** y **ciclos**.
#
# - Las **condiciones** evalúan si algo se cumple y, según la respuesta, siguen por un camino o por otro.
# - Los **ciclos** repiten una acción sobre cada elemento de un conjunto, o hasta que se cumpla una condición.
#
# Con estas dos cosas ya se puede escribir prácticamente cualquier programa.

# %% [markdown]
# ---

# %% [markdown]
# ### 🔀 Condicionales con `if`
#
# Un condicional tiene esta forma:
#
# ```
# if condición == True:
#     acción
# else:
#     otra acción
# ```
#
# Si hay varias condiciones, se amplía con `elif` (las veces que haga falta):
#
# ```
# if condición_1 == True:
#     acción
# elif condición_2 == True:
#     acción
# elif condición_3 == True:
#     acción
# ...
# else:
#     acción
# ```
#
# > 💡 Ojo con los **dos puntos** al final de cada línea y con la **sangría** (los espacios de la línea
# > de abajo). En Python la sangría no es decoración: es lo que le dice qué acción pertenece a qué
# > condición.

# %%
if 1 > 2:
    print('¡lógico!')
else:
    print('no es lógico :(')
# Out:
# no es lógico :(

# %%
if 2 > 1:
    print('¡lógico!')
else:
    print('no es lógico :(')
# Out:
# ¡lógico!

# %%
lugares_para_visitar = ['área 51', 'triángulo de las Bermudas', 'El Dorado']

# para las listas podemos usar 'in' y 'not in', que devuelven un booleano
if 'Atlántida' not in lugares_para_visitar:
    lugares_para_visitar.append('Atlántida')
else:
    lugares_para_visitar

lugares_para_visitar
# Out:
# ['área 51', 'triángulo de las Bermudas', 'El Dorado', 'Atlántida']

# %%
impresoras_en_stock = 100   # probá cambiarlo a 0, a 1 y a más de 1 para ver los tres resultados

if impresoras_en_stock == 0:
    impresoras_en_stock += 1   # este formato le suma 1 a la variable de la izquierda: otro buen truco para los ciclos
    print('Sin stock. Se emitió una orden de compra por', impresoras_en_stock, 'unidad')
elif impresoras_en_stock == 1:
    print('Última unidad en depósito:', impresoras_en_stock, '— conviene reponer')
else:
    print('Hay', impresoras_en_stock, 'unidades: no hace falta reponer')

# %% [markdown]
# ---

# %% [markdown]
# ### 🔁 Ciclos (`for`)
#
# Los **ciclos** recorren una secuencia de elementos (por ejemplo, una lista) y hacen algo con cada uno.
#
# El ciclo `for` es el más común. Tiene esta forma:
#
# ```
# for nombre_temporal in secuencia:
#     ... nombre_temporal ...
# ```
#
# Lo que hace Python es:
#
# 1. Toma el **primer** elemento de la secuencia y le pone temporalmente la etiqueta `nombre_temporal`.
# 2. Ejecuta la acción de abajo usando esa etiqueta.
# 3. Pasa al **siguiente** elemento y repite, hasta terminar la secuencia.
#
# > 💡 El nombre `nombre_temporal` lo elegís vos, y conviene que diga algo: si recorrés una lista de
# > sucursales, llamalo `sucursal`. El código se lee solo.

# %%
# Inicializar una lista vacía antes del ciclo nos permite ir agregándole elementos adentro
largo_de_los_nombres = []

for lugar in lugares_para_visitar:      # a cada elemento de la lista le pone temporalmente la etiqueta 'lugar'
    largo_de_los_nombres.append(len(lugar))   # y aplica esta acción a cada uno, de a uno

largo_de_los_nombres
# Out:
# [7, 25, 9, 9]

# %%
for indice, lugar in enumerate(lugares_para_visitar):   # enumerate() da el número de posición de cada elemento
    print('El lugar número', indice + 1, 'que quiero visitar es', lugar)
    # como la indexación arranca en 0, le sumamos 1 para que se lea natural
# Out:
# El lugar número 1 que quiero visitar es área 51
# El lugar número 2 que quiero visitar es triángulo de las Bermudas
# El lugar número 3 que quiero visitar es El Dorado
# El lugar número 4 que quiero visitar es Atlántida

# %%
lista_de_numeros = [10, 2, 6, 4, 8]

for numero in sorted(lista_de_numeros):
    print(numero ** 2)
# Out:
# 4
# 16
# 36
# 64
# 100

# %%
# Para practicar:

# Creá dos variables: manzanas con el valor 10 y naranjas con el valor 2.
#Creá una sentencia if que devuelva "¡Genial, más manzanas!" si manzanas es más grande que naranjas; de lo contrario, "¡Caramba, más naranjas!".

# %%
# Para practicar:

# Usá un if-statement para chequear que el Boolean value de True es 1, si es, imprmí 'Entonces... True es lo mismo que 1 en Python', sino imprimí 'Qué?'

# %%
# Para practicar:

# Creá un for-loop que devuelva una lista con el cuadrado de cada elemento de
# unidades_vendidas = [20, 2, 22, 0.2]

# %% [markdown]
# ---

# %% [markdown]
# ## 📖 Diccionarios
#
# Los **diccionarios** son otro tipo de dato. Aunque se parezcan a las listas, sirven para algo
# distinto: guardan la información como **pares clave-valor**. Hay una etiqueta (la **clave**) que
# corresponde a un valor.
#
# Eso hace que buscar sea directo: en vez de acordarte en qué posición estaba el dato, lo pedís
# **por su nombre**.
#
# Si pensás las claves como **nombres de columna** y los valores como el contenido de esa columna,
# ya estás viendo por qué los diccionarios se convierten tan fácil en las tablas que vamos a usar
# más adelante.
#
# Se escriben así:
#
# ```
# mi_diccionario = {'clave_1': valor_1, 'clave_2': valor_2}
# ```
#
# Con llaves `{}`, la clave y el valor separados por dos puntos, y los pares separados por comas.
# El valor de una clave puede ser, incluso, **otro diccionario**.

# %%
diccionario_nuevo = {}   # así se crea un diccionario vacío, para ir llenándolo en un ciclo

# %%
paises_y_capitales = {'Francia': 'París', 'Japón': 'Tokio', 'Brasil': 'Brasilia'}

paises_y_capitales.keys()   # ver las claves del diccionario

# %%
paises_y_capitales.values()   # ver los valores del diccionario

# %%
paises_y_capitales['Japón']   # buscar un valor puntual, por su clave

# %%
paises_y_capitales['Australia'] = 'Sídney'   # agregar un par nuevo (ojo, que está mal: lo corregimos abajo)

paises_y_capitales   # a diferencia de las listas, acá el orden no es lo que importa

# %%
paises_y_capitales['Australia'] = 'Canberra'   # asignar sobre una clave que ya existe la PISA

paises_y_capitales   # no se agregó un segundo 'Australia': se reemplazó el valor anterior

# %%
'Brasil' in paises_y_capitales   # con 'in' chequeamos si una clave existe

# %%
if 'Japón' in paises_y_capitales:   # esto es muy útil para armar condicionales
    print('¡Konnichiwa!')

# %%
if 'Italia' in paises_y_capitales:
    print('¡Ciao!')
else:
    print('Uh, ¡habría que agregarlo!')

# %%
# .items() permite recorrer claves y valores al mismo tiempo:
# devuelve una tupla (clave, valor) que podemos desarmar en dos variables
for clave, valor in paises_y_capitales.items():
    print('Así que', valor, 'es la capital de', clave, '.')

# %%
# Para practicar: creá un diccionario llamado responsables cuyas claves sean las cadenas
# 'ventas', 'logistica' y 'compras'.
# Asigná a cada área el nombre de quien la tiene a cargo.

# %%
# cambiá el responsable del área de ventas

# %%
# usá .update() en responsables con el siguiente diccionario como argumento; describí qué cambió:

# %%
# usá un ciclo for para imprimir esta oración para cada área:
# "El área de [área] está a cargo de [responsable]"

# %% [markdown]
# ### ⚖️ Tupla o diccionario: ¿cuál uso?
#
# Ya viste los dos y es **el momento exacto** en que se mezclan. Los dos guardan varias cosas juntas,
# pero responden preguntas distintas:
#
# | | 🔒 Tupla | 📖 Diccionario |
# |---|---|---|
# | **Cómo accedés** | Por **posición**: `t[0]` | Por **clave**: `d['sucursal']` |
# | **Se puede modificar** | ❌ Nunca | ✅ Sí |
# | **Tiene orden** | ✅ Sí, es lo único que la ordena | Conserva el de inserción, pero no se usa para buscar |
# | **Cuándo se usa** | Un dato fijo, con posiciones que ya sabés qué significan | Un dato con **nombre**, que puede cambiar o crecer |
# | **Se parece a** | Una **fila** de una tabla | Un **registro** con sus etiquetas |
#
# La pregunta que lo resuelve: **¿te acordás de memoria qué hay en la posición 2?**
# Si la respuesta es no, usá un diccionario.

# %%
# La MISMA información guardada de las dos formas

# Como tupla: compacta, pero hay que recordar qué significa cada posición
venta_tupla = ('Sucursal Centro', 'monitores', 12, 340000)
print("Unidades vendidas:", venta_tupla[2], "  ← ¿estabas seguro de que era la posición 2?")

# Como diccionario: cada dato dice qué es
venta_dicc = {
    'sucursal': 'Sucursal Centro',
    'producto': 'monitores',
    'unidades': 12,
    'precio': 340000
}
print("Unidades vendidas:", venta_dicc['unidades'], "  ← acá no hay nada que recordar")

# Y el diccionario se puede corregir; la tupla no
venta_dicc['unidades'] = 15
print("\nCorregido:", venta_dicc)
# Out:
# Unidades vendidas: 12   ← ¿estabas seguro de que era la posición 2?
# Unidades vendidas: 12   ← acá no hay nada que recordar
#
# Corregido: {'sucursal': 'Sucursal Centro', 'producto': 'monitores', 'unidades': 15, 'precio': 340000}

# %% [markdown]
# > 💡 **Por qué esto importa para lo que viene:** cuando pasemos a pandas, un **DataFrame** es
# > básicamente una lista de registros con nombre. Las columnas son las claves del diccionario y
# > cada fila es una tupla de valores. Si entendés esta diferencia ahora, `df['ventas']` va a ser obvio.

# %% [markdown]
# ---
# ## 🗂️ El `groupby` a mano: acumular por categoría
#
# Este es **el patrón de negocio más importante** de toda la programación básica, y el puente directo
# hacia pandas.
#
# La pregunta es siempre la misma: *"tengo una lista de operaciones, ¿cuánto suma cada categoría?"*
#
# La receta tiene tres pasos:
# 1. Empezar con un **diccionario vacío**.
# 2. Recorrer los datos.
# 3. Por cada uno, sumarlo en la clave que corresponda.

# %%
#Lista + diccionario
operaciones = [
    {"ciudad": "Córdoba",  "producto": "Notebook", "monto": 890000},
    {"ciudad": "Rosario",  "producto": "Mouse",    "monto":  12500},
    {"ciudad": "Córdoba",  "producto": "Monitor",  "monto": 340000},
    {"ciudad": "Mendoza",  "producto": "Notebook", "monto": 890000},
    {"ciudad": "Rosario",  "producto": "Monitor",  "monto": 340000},
    {"ciudad": "Córdoba",  "producto": "Mouse",    "monto":  12500},
]

# Paso 1: un diccionario vacío para acumular
total_por_ciudad = {}

# Paso 2 y 3: recorrer y acumular
for op in operaciones:
    ciudad = op["ciudad"]
    # .get(clave, 0) devuelve el valor si la clave existe, y 0 si es la primera vez
    total_por_ciudad[ciudad] = total_por_ciudad.get(ciudad, 0) + op["monto"]

print("Facturación por ciudad:")
for ciudad, total in total_por_ciudad.items():
    print(f"   {ciudad:<10} $ {total:>10,.0f}")
# Out:
# Facturación por ciudad:
#    Córdoba    $  1,242,500
#    Rosario    $    352,500
#    Mendoza    $    890,000

# %%
# Contar cuántas operaciones hubo en cada ciudad (mismo patrón, sumando 1)
cantidad_por_ciudad = {}
for op in operaciones:
    cantidad_por_ciudad[op["ciudad"]] = cantidad_por_ciudad.get(op["ciudad"], 0) + 1

print("Operaciones por ciudad:", cantidad_por_ciudad)

# Y el ticket promedio, combinando los dos diccionarios
print("\nTicket promedio:")
for ciudad in total_por_ciudad:
    promedio = total_por_ciudad[ciudad] / cantidad_por_ciudad[ciudad]
    print(f"   {ciudad:<10} $ {promedio:>10,.0f}")
# Out:
# Operaciones por ciudad: {'Córdoba': 3, 'Rosario': 2, 'Mendoza': 1}
#
# Ticket promedio:
#    Córdoba    $    414,167
#    Rosario    $    176,250
#    Mendoza    $    890,000

# %% [markdown]
# ### 🎯 Por qué esto importa
#
# Acabás de escribir a mano lo que en pandas es **una sola línea**:
#
# ```python
# df.groupby("ciudad")["monto"].sum()
# ```
#
# Cuando lleguemos a esa línea, no va a ser magia: vas a saber exactamente qué está haciendo por dentro.
# **Ese es el objetivo de esta clase.**

# %% [markdown]
# ## 🛠️ Funciones
#
# Python trae muchísimas **funciones** que hacen tareas específicas. Ya usamos una: `print()`.
# Y si no existe una función que haga lo que necesitás, **podés crear la tuya**.
#
# Adentro de los paréntesis van los **argumentos**: los datos con los que la función va a trabajar.
# Se separan con comas.

# %% [markdown]
# ---

# %% [markdown]
# ### 🏗️ Funciones predefinidas
#
# Python incluye de fábrica un conjunto de funciones para las tareas más básicas. Para casi todo lo
# demás vas a necesitar **importar una librería** (como hicimos con NumPy o pandas).
#
# Algunos ejemplos de funciones que ya vienen incluidas:

# %%
round(3.14, 1)   # round() toma 2 argumentos: el número a redondear y cuántos decimales querés
# Out:
# 3.1

# %% [markdown]
# Algunas funciones permiten (o exigen) que le pongas **nombre** al argumento. Por ejemplo, `print()`
# acepta un separador entre los elementos que imprime: se indica escribiendo `sep=` y el carácter que
# querés que aparezca en el medio.

# %%
print('por', 'favor', 'traé', 'facturas', sep='...')
# Out:
# por...favor...traé...facturas

# %% [markdown]
# La lista completa de funciones que Python trae incorporadas está acá:
# https://docs.python.org/3/library/functions.html
#
# Algunas de las más importantes son las que **convierten** una variable de un tipo a otro, como
# `str()`, `int()`, `float()`, `list()` o `set()`.
#
# De todos modos, en la mayoría de los casos vas a cargar una **librería** que suma un montón de
# funciones nuevas a las que ya vienen incluidas.

# %% [markdown]
# ---

# %% [markdown]
# ### ✏️ Crear tus propias funciones
#
# Crear una función es muy simple. La forma es:
#
# ```
# def nombre_de_la_funcion(arg1, arg2=valor_por_defecto, arg3...):
#     ...arg1...arg2...arg3...
#     return resultado
# ```
#
# Tres cosas para tener en cuenta:
#
# - **`def`** avisa que estás definiendo una función, y después va el nombre que elijas.
# - Un argumento puede tener un **valor por defecto**: si no se lo pasás al llamarla, usa ese.
# - **`return`** es lo que la función **devuelve**. Sin `return`, la función hace lo suyo pero no te
#   entrega nada que puedas guardar en una variable.

# %%
def dividir_por_dos(x):
    return x / 2

dividir_por_dos(500)
# Out:
# 250.0

# %%
def agregar_pausa_dramatica(palabra1, palabra2, nivel_de_drama=1):
    """ Pone la cantidad deseada de puntos suspensivos entre dos palabras.
    Muy útil si querés mucho drama. """   # con tres comillas se describe qué hace la función
    frase_dramatica = palabra1 + '...' * nivel_de_drama + palabra2
    return frase_dramatica

# como nivel_de_drama ya tiene el valor por defecto 1, podemos no pasarlo
agregar_pausa_dramatica('Voy a volver', '¡nunca!')
# Out:
# 'Voy a volver...¡nunca!'

# %%
# usando return, el resultado se puede guardar en una variable
ultimas_palabras = agregar_pausa_dramatica('por favor', 'traeme un sanguche de milanesa', nivel_de_drama=3)

ultimas_palabras
# Out:
# 'por favor.........traeme una factura'

# %%
def crear_polemica_de_pizza():   # una función puede ser, simplemente, la ejecución de otras funciones
    drama_pizza = agregar_pausa_dramatica('En mi opinión', 'el anana no va en la pizza', nivel_de_drama=2)
    return drama_pizza

crear_polemica_de_pizza()
# Out:
# 'En mi opinión......la piña no va en la pizza'

# %% [markdown]
# ---

# %% [markdown]
# ## ❓ Ayuda
#
# Usá `help()` para obtener más información sobre cualquier clase de un objeto o función. Usar comillas es opcional. Si necesitás ayuda sobre una función específica en una librería, primero debás instalarla e importarla.
#
# Si escribís `help()` sin argumentos, Python te va a preguntar qué necesitás.
#
# Suele ser recomendable leer sobre los diferentes elementos de Python desde el sitio web o los creadores de sus librerías (https://www.python.org/about/help/).

# %%
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(*args, sep=' ', end='\n', file=None, flush=False)
#     Prints the values to a stream, or to sys.stdout by default.
#
#     sep
#       string inserted between values, default a space.
#     end
#       string appended after the last value, default a newline.
#     file
#       a file-like object (stream); defaults to the current sys.stdout.
#     flush
#       whether to forcibly flush the stream.

# %%
help('print')
# Out:
# Help on built-in function print in module builtins:
#
# print(*args, sep=' ', end='\n', file=None, flush=False)
#     Prints the values to a stream, or to sys.stdout by default.
#
#     sep
#       string inserted between values, default a space.
#     end
#       string appended after the last value, default a newline.
#     file
#       a file-like object (stream); defaults to the current sys.stdout.
#     flush
#       whether to forcibly flush the stream.

# %% [markdown]
# Si sos perezoso al escribir, como yo, también podés usar la siguiente forma abreviada para obtener el mismo tipo de output de ayuda.

# %%
print?
# Out:
# Signature: print(*args, sep=' ', end='\n', file=None, flush=False)
# Docstring:
# Prints the values to a stream, or to sys.stdout by default.
#
# sep
#   string inserted between values, default a space.
# end
#   string appended after the last value, default a newline.
# file
#   a file-like object (stream); defaults to the current sys.stdout.
# flush
#   whether to forcibly flush the stream.
# Type:      builtin_function_or_method

# %% [markdown]
# ---

# %% [markdown]
# # 📚 Más información
#
# Se recomienda familiarizarse con los fundamentos de Python para aprovechar todo su potencial. ACá hay principalmente documentación oficial sobre los temas mencionados. Existen muchos otros blogs y videos que explican estos fundamentos con gran detalle. Puede ser útil escuchar estos conceptos varias veces de diferentes personas para comprenderlos por completo.
#
# Documentación de Jupyter Notebook: https://jupyter-notebook.readthedocs.io/en/stable/
#
# Operaciones matemáticas en Python: https://docs.python.org/2.4/lib/typesnumeric.html
#
# Documentación de Python sobre tipos de datos simples: https://docs.python.org/3/library/stdtypes.html
#
# Documentación para Ciclos (for): https://docs.python.org/3/tutorial/controlflow.html
#
# Documentación para funciones: https://docs.python.org/3/tutorial/controlflow.html#defining-functions
#
#
# Documentación para instalación de paquetes: https://packaging.python.org/tutorials/installing-packages/
#
# NumPy Beginner's Tutorial de la página oficial: https://numpy.org/doc/stable/user/absolute_beginners.html
#
# pandas Beginner's 10 min Tutorial de la página oficial: https://pandas.pydata.org/docs/user_guide/10min.html#min

# %%
#@title Easter egg 🥚
from IPython.display import Image
Image(url='https://media2.giphy.com/media/v1.Y2lkPTc5MGI3NjExZnJodGQ4ZXVvYnFncnJpc3VjOHdqZmF2ZGZscHFscTR5OHJjbnNsbiZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/Ws6T5PN7wHv3cY8xy8/giphy.gif')
# Out:
# <img src="https://media2.giphy.com/media/v1.Y2lkPTc5MGI3NjExZnJodGQ4ZXVvYnFncnJpc3VjOHdqZmF2ZGZscHFscTR5OHJjbnNsbiZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/Ws6T5PN7wHv3cY8xy8/giphy.gif"/>
