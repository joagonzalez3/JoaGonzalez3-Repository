# %% [markdown]
# <a href="https://colab.research.google.com/github/Datso653/Laboratorio-de-metodos-Cuantitativos-Aplicados-a-la-gestion/blob/main/notebooks/02%20-%20Clase_Visualizaci%C3%B3n_de_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Laboratorio de Métodos Cuantitativos Aplicados a la Gestión**

# %% [markdown]
# Clase - Visualización de datos
#
# ---

# %%
#paso 1 importar las librerías que se van a utilizar
import pandas as pd #para manipular los archivos
import matplotlib.pyplot as plt #para hacer gráficos
import seaborn as sb #para hacer gráficos
import numpy as np #para realizar operaciones matemáticas

# %% [markdown]
# ---
# Caso 1 - Análisis inicial de una base de datos
#
# ---

# %% [markdown]
# El dataset Carseats contiene datos simulados sobre las ventas de asientos para niños en 400 tiendas diferentes. Este conjunto de datos incluye las siguientes variables:
#
# Sales: Ventas unitarias (en miles) en cada ubicación.
#
# CompPrice: Precio cobrado por el competidor en cada ubicación.
#
# Income: Nivel de ingresos de la comunidad (en miles de dólares).
#
# Advertising: Presupuesto de publicidad local para la empresa en cada ubicación (en miles de dólares).
#
# Population: Tamaño de la población en la región (en miles).
#
# Price: Precio que la empresa cobra por los asientos para niños en cada sitio.
#
# ShelveLoc: Calidad de la ubicación en los estantes para los asientos (con niveles: Malo, Bueno y Medio).
#
# Age: Edad promedio de la población local.
#
# Education: Nivel educativo en cada ubicación.
#
# Urban: Indicador de si la tienda está en una zona urbana o rural.
#
# US: Indicador de si la tienda está en los EE. UU. o no.

# %%
#Cargamos un conjunto de datos
#Em este caso lo importamos desde la web
url = 'https://raw.githubusercontent.com/selva86/datasets/master/Carseats.csv'
#le pedimos a pandas que lo lea y le asignamos un nombre para crear el dataframe
datos = pd.read_csv(url)
datos
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0     9.50        138      73           11         276    120       Bad   42
# 1    11.22        111      48           16         260     83      Good   65
# 2    10.06        113      35           10         269     80    Medium   59
# 3     7.40        117     100            4         466     97    Medium   55
# 4     4.15        141      64            3         340    128       Bad   38
# ..     ...        ...     ...          ...         ...    ...       ...  ...
# 395  12.57        138     108           17         203    128      Good   33
# 396   6.14        139      23            3          37    120    Medium   55
# 397   7.41        162      26           12         368    159    Medium   40
# 398   5.94        100      79            7         284     95       Bad   50
# 399   9.71        134      37            0          27    120      Good   49
#
#      Education Urban   US
# ...

# %%
#vemos los primeros 5 registros
datos.head(5)
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0   9.50        138      73           11         276    120       Bad   42
# 1  11.22        111      48           16         260     83      Good   65
# 2  10.06        113      35           10         269     80    Medium   59
# 3   7.40        117     100            4         466     97    Medium   55
# 4   4.15        141      64            3         340    128       Bad   38
#
#    Education Urban   US
# 0         17   Yes  Yes
# 1         10   Yes  Yes
# 2         12   Yes  Yes
# 3         14   Yes  Yes
# 4         13   Yes   No

# %%
#vemos los últimos 3 registros
datos.tail(7)
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 393   5.57        109      51           10          26    120    Medium   30
# 394   5.35        130      58           19         366    139       Bad   33
# 395  12.57        138     108           17         203    128      Good   33
# 396   6.14        139      23            3          37    120    Medium   55
# 397   7.41        162      26           12         368    159    Medium   40
# 398   5.94        100      79            7         284     95       Bad   50
# 399   9.71        134      37            0          27    120      Good   49
#
#      Education Urban   US
# 393         17    No  Yes
# 394         16   Yes  Yes
# 395         14   Yes  Yes
# 396         11    No  Yes
# 397         18   Yes  Yes
# 398         12   Yes  Yes
# 399         16   Yes  Yes

# %%
#inspeccionamos el archivo con la función info
#Devuelve: número de filas, número y tipo de columnas,índice y memoria usada
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sales        400 non-null    float64
#  1   CompPrice    400 non-null    int64
#  2   Income       400 non-null    int64
#  3   Advertising  400 non-null    int64
#  4   Population   400 non-null    int64
#  5   Price        400 non-null    int64
#  6   ShelveLoc    400 non-null    object
#  7   Age          400 non-null    int64
#  8   Education    400 non-null    int64
#  9   Urban        400 non-null    object
#  10  US           400 non-null    object
# dtypes: float64(1), int64(7), object(3)
# memory usage: 34.5+ KB

# %%
#Exploramos el índice (filas)
datos.index
# Out:
# RangeIndex(start=0, stop=400, step=1)

# %%
#Vemos los parámetros principales de las variables cuantitativas
datos.describe().transpose()
# Out:
#              count        mean         std   min     25%     50%     75%  \
# Sales        400.0    7.496325    2.824115   0.0    5.39    7.49    9.32
# CompPrice    400.0  124.975000   15.334512  77.0  115.00  125.00  135.00
# Income       400.0   68.657500   27.986037  21.0   42.75   69.00   91.00
# Advertising  400.0    6.635000    6.650364   0.0    0.00    5.00   12.00
# Population   400.0  264.840000  147.376436  10.0  139.00  272.00  398.50
# Price        400.0  115.795000   23.676664  24.0  100.00  117.00  131.00
# Age          400.0   53.322500   16.200297  25.0   39.75   54.50   66.00
# Education    400.0   13.900000    2.620528  10.0   12.00   14.00   16.00
#
#                 max
# Sales         16.27
# CompPrice    175.00
# Income       120.00
# Advertising   29.00
# Population   509.00
# Price        191.00
# Age           80.00
# Education     18.00

# %%
# Otras operaciones son:
print(datos["Sales"].min()) # Minimo
print(datos["Sales"].max()) # Maximo
print(datos["Sales"].count()) # Cantidad
print(datos["Sales"].idxmax()) # El Ìndice del valor máximo
print(datos["Sales"].idxmin()) # El Ìndice del valor mínimo
print(datos["Sales"].quantile([.25,.5,.75])) # Los quantiles
print(datos["Sales"].skew()) # Asimetria
print(datos["Sales"].kurtosis()) # Kurtosis
# Out:
# 0.0
# 16.27
# 400
# 376
# 174
# 0.25    5.39
# 0.50    7.49
# 0.75    9.32
# Name: Sales, dtype: float64
# 0.18556036318721578
# -0.08087736743346197

# %%
#también se puede armar un archivo que contenga una columna en particular
precios=datos["Price"]
precios
# Out:
# 0      120
# 1       83
# 2       80
# 3       97
# 4      128
#       ...
# 395    128
# 396    120
# 397    159
# 398     95
# 399    120
# Name: Price, Length: 400, dtype: int64

# %%
ventas=datos["Sales"]
ventas
# Out:
# 0       9.50
# 1      11.22
# 2      10.06
# 3       7.40
# 4       4.15
#        ...
# 395    12.57
# 396     6.14
# 397     7.41
# 398     5.94
# 399     9.71
# Name: Sales, Length: 400, dtype: float64

# %%
#sumamos las ventas totales
ventas.sum()
# Out:
# np.float64(2998.53)

# %%
#vemos la media de las ventas
ventas.mean()
# Out:
# np.float64(7.496325000000001)

# %%
#vemos los datos únicos de una columna
datos["Sales"].unique()
# Out:
# array([ 9.5 , 11.22, 10.06,  7.4 ,  4.15, 10.81,  6.63, 11.85,  6.54,
#         4.69,  9.01, 11.96,  3.98, 10.96, 11.17,  8.71,  7.58, 12.29,
#        13.91,  8.73,  6.41, 12.13,  5.08,  5.87, 10.14, 14.9 ,  8.33,
#         5.27,  2.99,  7.81, 13.55,  8.25,  6.2 ,  8.77,  2.67, 11.07,
#         8.89,  4.95,  6.59,  3.24,  2.07,  7.96, 10.43,  4.12,  4.16,
#         4.56, 12.44,  4.38,  3.91, 10.61,  1.42,  4.42,  7.91,  6.92,
#         4.9 ,  6.85, 11.91,  0.91,  5.42,  5.21,  8.32,  7.32,  1.82,
#         8.47,  7.8 ,  8.85, 13.39,  7.99,  9.46,  6.5 ,  5.52, 12.61,
#         8.55, 10.64,  7.7 ,  4.43,  9.14,  8.01,  7.52, 11.62,  2.23,
#         8.7 , 11.7 ,  6.56,  7.95,  5.33,  4.81,  4.53,  8.86,  8.39,
#         5.58,  9.48,  7.45, 12.49,  4.88,  4.11,  5.3 ,  5.07,  4.62,
#         5.55,  0.16,  3.47,  8.98,  9.  ,  6.62,  6.67,  6.01,  9.31,
#         8.54,  8.8 ,  7.57,  7.37,  6.87, 11.67,  6.88,  8.19,  8.87,
# ...

# %%
#creamos una nueva variable a partir de otras
#generamos una columna que clasifique las ventas

datos.loc[datos["Sales"] <=5 , 'Tipo de ventas'] = "Bajas"

datos.loc[(5<datos["Sales"]) & (datos["Sales"] <=10) , 'Tipo de ventas'] = "Medianas"


datos.loc[datos["Sales"]>10 , 'Tipo de ventas'] = "Altas"

datos
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0     9.50        138      73           11         276    120       Bad   42
# 1    11.22        111      48           16         260     83      Good   65
# 2    10.06        113      35           10         269     80    Medium   59
# 3     7.40        117     100            4         466     97    Medium   55
# 4     4.15        141      64            3         340    128       Bad   38
# ..     ...        ...     ...          ...         ...    ...       ...  ...
# 395  12.57        138     108           17         203    128      Good   33
# 396   6.14        139      23            3          37    120    Medium   55
# 397   7.41        162      26           12         368    159    Medium   40
# 398   5.94        100      79            7         284     95       Bad   50
# 399   9.71        134      37            0          27    120      Good   49
#
#      Education Urban   US Tipo de ventas
# ...

# %% [markdown]
# Visualizamos datos puntuales con distintos gráficos
#
# ---

# %%
#Hacemos un gráfico de barras verticales
calidad=datos.groupby("ShelveLoc").count()["Sales"]
calidad.plot(kind="bar",title="Cantidad de casos por calidad",color="tab:orange")
# Out:
# <Axes: title={'center': 'Cantidad de casos por calidad'}, xlabel='ShelveLoc'>

# %%
calidad
# Out:
# ShelveLoc
# Bad        96
# Good       85
# Medium    219
# Name: Sales, dtype: int64

# %%
#Hacemos un gráfico de barras horizontales
calidad=datos.groupby("ShelveLoc").count()["Sales"]
calidad.plot(kind="barh",title="Cantidad de casos por calidad",color="tab:green")
# Out:
# <Axes: title={'center': 'Cantidad de casos por calidad'}, ylabel='ShelveLoc'>

# %%
#realizamos el gráfico con seaborn
sb.countplot(x="ShelveLoc",data=datos)
plt.xticks(rotation=90)
plt.show()

# %%
#Hacemos un gráfico de torta
datos["Tipo de ventas"].value_counts().plot.pie(startangle=45,autopct="%.1f%%",title="Proporción según perfil de ventas")
# Out:
# <Axes: title={'center': 'Proporción según perfil de ventas'}, ylabel='count'>

# %%
#Hacemos un gráfico de torta
datos["Urban"].value_counts().plot.pie(startangle=45,autopct="%.1f%%",title="Proporción de tiendas urbanas")
# Out:
# <Axes: title={'center': 'Proporción de tiendas urbanas'}, ylabel='count'>

# %%
#Histogramas

datos.hist("Sales")
plt.xlabel("Ventas")
plt.ylabel("Frecuencia")
plt.show()

# %%
#Inspeccionamos los precios de venta de las tiendas y de sis competidores
#Lo hacemos a traves de un Histograma que nos muestra la distribución de ambos
datos.hist(["Price","CompPrice"],color="green")
plt.xlabel("Precios")
plt.ylabel("Frecuencia de casos")

plt.show()

# %%
#Diagrama de dispersión
datos.plot(kind = 'scatter', x='Price', y='Sales')
plt.xlabel('Precios')
plt.ylabel("Ventas")
plt.ticklabel_format(style='plain', axis='y')

# %%
#hacemos un boxplot
sb.boxplot(data=datos["Sales"])
plt.ticklabel_format(style="plain",axis="y")

# %%
sb.boxplot(data=datos[["Price","CompPrice"]])
plt.ticklabel_format(style="plain",axis="y")

# %%
#Visualizamos la cantidad de tiendas segun su presupuesto en publicidad
#realizamos el gráfico de barras con seaborn
sb.countplot(x="Advertising",data=datos)
plt.xticks(rotation=90)
plt.xlabel("Presupuesto (miles de dólares)")
plt.ylabel("Cantidad de casos")
plt.title("Cantidad de casos por presupuesto para publicidad")
plt.show()

# %%
#Exportando a Excel
datos.to_excel("datos.xlsx", index=True)

# %% [markdown]
# ✅ Ejemplos de armado de distintos tipos de gráficos
#
# ---

# %%
## Grafica de barras horizontales

## Declaramos valores para el eje y, en este caso son categorias
eje_x = ['Programacion', 'Física', 'Matematicas', 'Química']

## Declaramos valores para el eje x, ahora son los valores
eje_y = [76,31,45,57]

## Creamos Gráfica
plt.barh(eje_x, eje_y, color="green")
plt.ylabel('Cursos')
plt.xlabel('Cantidad de Aprobados')
plt.title('Estudiantes aprobados por curso')
plt.show()

# %%
## Gráfico de barras agrupadas

serie_1 = [1089, 1287, 842, 957, 1485]
serie_2 = [1126, 1453, 735, 1078, 1512]


numero_de_grupos = len(serie_1)
indice_barras = np.arange(numero_de_grupos)
ancho_barras =0.40

plt.bar(indice_barras, serie_1, width=ancho_barras, label='Hombres')
plt.bar(indice_barras + ancho_barras, serie_2, width=ancho_barras, label='Mujeres')
plt.legend(loc='best')
## Se colocan los indicadores en el eje x
plt.xticks(indice_barras + ancho_barras, ('Norte', 'Este', 'Sur', 'Oeste','Centro'))

plt.ylabel('Numero de nacimientos')
plt.xlabel('Zona')
plt.title('Nacimientos por genero y Región')

plt.show()

# %%
## Grafica de Barras apiladas

grupos = ['Grupo 1', 'Grupo 2', 'Grupo 3', 'Grupo 4']
Medicamento_A = [286,450,304,808]
Medicamento_B= [325,732,370,200]

indice = np.arange(len(grupos))

## Se crean las primeras barras
plt.bar(indice, Medicamento_A, label='Medicamento A')

## Se crean las segundas barras y se apilan sobre las primeras
plt.bar(indice, Medicamento_B, label='Medicamento B',  bottom=Medicamento_A)

plt.xticks(indice, grupos)
plt.ylabel("Número de pacientes")
plt.xlabel("Grupos")
plt.title('Pacientes según tratamiento recibido')
plt.legend()

plt.show()

# %% [markdown]
# ---
#
# Caso 2 - Campaña publicitaria
#
# ---

# %% [markdown]
# ✅ Veamos otro ejemplo, pero esta vez vamos a subir la base de datos desde nuestra computadora
#
# ---
#
# ![Captura de Pantalla 2025-07-12 a la(s) 02.27.47.png](data:image/png;base64,...)

# %% [markdown]
# Planteo del problema
#
#
# ---
#
# Una cadena de comida rápida planea agregar un nuevo artículo a su menú. Sin embargo, todavía están indecisos entre tres posibles campañas de marketing para promocionar el nuevo producto. Para determinar qué promoción tiene el mayor efecto sobre las ventas, el nuevo artículo se introduce en ubicaciones de varios mercados seleccionados al azar. Se utiliza una promoción diferente en cada ubicación y las ventas semanales del nuevo artículo se registran durante las primeras cuatro semanas.
#
# Dataset:
#
# MarketID: identificador único para el mercado
#
# MarketSize: tamaño del área de mercado por ventas
#
# LocationID: identificador único para la ubicación de la tienda
#
# AgeOfStore: antigüedad de la tienda en años
#
# Promoción: una de las tres promociones que se probaron
#
# Semana: una de las cuatro semanas en las que se realizaron las promociones.
#
# SalesInThousands: monto de ventas para un ID

# %% [markdown]
# Objetivo:
# el objetivo en este caso es determinar cuál de las tres campañas de marketing genera las mayores ventas para el nuevo elemento del menú.

# %% [markdown]
# Análisis de datos:
#
# 1- Analizamos los datos comparando los montos de venta de cada promoción.
#
# 2- Calculamos las ventas promedio por semana para cada promoción en todas las ubicaciones.
#
# 3- Analizamos los datos segmentándolos según tamaño del área del mercado o antigüedad para comprender cómo los diferentes factores pueden influir en el éxito de cada promoción.
#
# 4- Filtramos los datos por Promoción (Promoción 1, Promoción 2 y Promoción 3).
# Para cada promoción, sume la columna SalesInThousands.
# Divida las ventas totales por la cantidad de semanas para obtener el promedio de ventas semanales para cada promoción.
#
# 5-Evaluamos los resultados: compare las ventas semanales promedio de cada promoción para determinar cuál tuvo el mejor desempeño. Considere cualquier información adicional que haya obtenido al segmentar los datos según MarketSize o AgeOfStore.

# %%
#paso 2 importar el conjunto de datos
data=pd.read_csv("WA_Marketing-Campaign.csv",header=0)
data
# Out:
#      MarketID MarketSize  LocationID  AgeOfStore  Promotion  week  \
# 0           1     Medium           1           4          3     1
# 1           1     Medium           1           4          3     2
# 2           1     Medium           1           4          3     3
# 3           1     Medium           1           4          3     4
# 4           1     Medium           2           5          2     1
# ..        ...        ...         ...         ...        ...   ...
# 543        10      Large         919           2          1     4
# 544        10      Large         920          14          2     1
# 545        10      Large         920          14          2     2
# 546        10      Large         920          14          2     3
# 547        10      Large         920          14          2     4
#
#      SalesInThousands
# 0               33.73
# 1               35.67
# 2               29.03
# 3               39.25
# 4               27.81
# ..                ...
# ...

# %%
#paso 3 - vemos si hay datos faltantes y características de las variables
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 548 entries, 0 to 547
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   MarketID          548 non-null    int64
#  1   MarketSize        548 non-null    object
#  2   LocationID        548 non-null    int64
#  3   AgeOfStore        548 non-null    int64
#  4   Promotion         548 non-null    int64
#  5   week              548 non-null    int64
#  6   SalesInThousands  548 non-null    float64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 30.1+ KB

# %%
#paso 4 Evaluar parámetros estadísticos principales
data.describe().transpose()
# Out:
#                   count        mean         std    min      25%    50%  \
# MarketID          548.0    5.715328    2.877001   1.00    3.000    6.0
# LocationID        548.0  479.656934  287.973679   1.00  216.000  504.0
# AgeOfStore        548.0    8.503650    6.638345   1.00    4.000    7.0
# Promotion         548.0    2.029197    0.810729   1.00    1.000    2.0
# week              548.0    2.500000    1.119055   1.00    1.750    2.5
# SalesInThousands  548.0   53.466204   16.755216  17.34   42.545   50.2
#
#                        75%     max
# MarketID            8.0000   10.00
# LocationID        708.0000  920.00
# AgeOfStore         12.0000   28.00
# Promotion           3.0000    3.00
# week                3.2500    4.00
# SalesInThousands   60.4775   99.65

# %%
#realizamos el gráfico con seaborn para ver tamaño  de mercado
sb.countplot(x="MarketSize",data=data)
plt.title("Cantidad de casos por tamaño de mercado")
plt.xlabel("Tamaño de mercado")
plt.ylabel("Cantidad de casos")
plt.show()

# %%
#Hacemos un gráfico de torta para ver frecuencia relativa de promociones
data["Promotion"].value_counts().plot.pie(startangle=45,autopct="%.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
sb.boxplot(x="Promotion", y="SalesInThousands", data=data)
plt.title("ventas distribuídas por promoción")
plt.xlabel("Promoción")
plt.ylabel("Ventas en miles usd")
plt.show()

# %%
# Visualizamos las ventas promedio por tamaño de mercado y promoción
grupos = data.groupby(["MarketSize", "Promotion"])["SalesInThousands"].mean().reset_index()
sb.barplot(x="MarketSize", y="SalesInThousands", hue="Promotion", data=grupos)
plt.title("Ventas promedio por tamaño de mercado y promoción")
plt.xlabel("Tamaño de mercado")
plt.ylabel("Ventas en miles usd")
plt.show()

# %%
# Visualice las ventas promedio por AgeOfStore y Promoción (usando grupos de edad)
data["AgeBin"] = pd.cut(data["AgeOfStore"], bins=[0, 5, 10, 15, 20, 25, 30], labels=["0-5", "6-10", "11-15", "16-20", "21-25", "26-30"])
edades = data.groupby(["AgeBin", "Promotion"])["SalesInThousands"].mean().reset_index()
sb.barplot(x="AgeBin", y="SalesInThousands", hue="Promotion", data=edades)
plt.title("Ventas promedio por antigüedad de la tienda y promoción")
plt.xlabel("Grupos de edades")
plt.ylabel("Ventas en miles usd")
plt.show()
# Out:
# /tmp/ipykernel_2474/3101456697.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   edades = data.groupby(["AgeBin", "Promotion"])["SalesInThousands"].mean().reset_index()

# %%
#vemos las ventas semanales promedio por promoción y evaluamos
ventas = data.groupby(["Promotion", "week"])["SalesInThousands"].sum().reset_index()
ventas_semanales_promedio = ventas.groupby("Promotion")["SalesInThousands"].mean().reset_index()

# %%
print(ventas_semanales_promedio)
mejor_promocion = ventas_semanales_promedio.loc[ventas_semanales_promedio["SalesInThousands"].idxmax()]["Promotion"]
print(f"La promoción elegida es: {mejor_promocion}")
# Out:
#    Promotion  SalesInThousands
# 0          1         2498.2575
# 1          2         2224.4825
# 2          3         2602.1300
# La promoción elegida es: 3.0

# %%
#vemos las ventas semanales promedio por promoción y evaluamos
ventas = data.groupby(["Promotion", "week"])["SalesInThousands"].sum().reset_index()
ventas_semanales_promedio = ventas.groupby("Promotion")["SalesInThousands"].mean().reset_index()
sb.barplot(x="Promotion", y="SalesInThousands", data=ventas_semanales_promedio)
plt.title("Ventas semanales promedio por promoción")
plt.xlabel("Promoción")
plt.ylabel("Ventas en miles usd")
plt.show()

# %% [markdown]
# ---
#
#
# Caso 3 - Vamos a generar una base Simulada de un supermercado
#
# ---

# %%
# Crear datos ficticios para un archivo Supermarket_Sales.csv
np.random.seed(42) # para reproducibilidad

productos = ['Leche', 'Yogur', 'Queso', 'Carne Res', 'Pollo', 'Pescado', 'Manzanas', 'Bananas', 'Lechuga', 'Pan Blanco', 'Galletas']
categorias_map = {
    'Leche': 'Lácteos',
    'Yogur': 'Lácteos',
    'Queso': 'Lácteos',
    'Carne Res': 'Carnes',
    'Pollo': 'Carnes',
    'Pescado': 'Carnes',
    'Manzanas': 'Frutas y Verduras',
    'Bananas': 'Frutas y Verduras',
    'Lechuga': 'Frutas y Verduras',
    'Pan Blanco': 'Panadería',
    'Galletas': 'Panadería'
}

regiones = ['Norte', 'Sur', 'Este', 'Oeste']

# Generar nombres de productos aleatorios
nombres_productos_generados = np.random.choice(productos, 1000)

# Asignar categorías basadas en el mapeo
categorias_generadas = [categorias_map[prod] for prod in nombres_productos_generados]

data = {
    'nombre_producto': nombres_productos_generados,
    'categoria': categorias_generadas,
    'fecha_venta': pd.to_datetime('2025-01-01') + pd.to_timedelta(np.random.randint(0, 365, 1000), unit='D'),
    'unidades_vendidas_diarias': np.random.randint(10, 200, 1000),
    'precio_unitario': np.round(np.random.uniform(1.5, 50, 1000), 2),
    'costo_unitario': np.round(np.random.uniform(0.5, 30, 1000), 2),
    'region': np.random.choice(regiones, 1000)
}
df_supermarket = pd.DataFrame(data)
df_supermarket
# Out:
#     nombre_producto          categoria fecha_venta  unidades_vendidas_diarias  \
# 0          Manzanas  Frutas y Verduras  2025-10-22                         64
# 1         Carne Res             Carnes  2025-04-14                        128
# 2          Galletas          Panadería  2025-01-14                        180
# 3           Bananas  Frutas y Verduras  2025-10-15                        167
# 4             Pollo             Carnes  2025-06-28                        123
# ..              ...                ...         ...                        ...
# 995      Pan Blanco          Panadería  2025-12-24                         49
# 996         Lechuga  Frutas y Verduras  2025-01-05                        170
# 997           Yogur            Lácteos  2025-03-27                        138
# 998         Bananas  Frutas y Verduras  2025-06-24                         17
# 999         Bananas  Frutas y Verduras  2025-10-17                        110
#
# ...

# %% [markdown]
# Ahora generamos más variables a partir de otras

# %%
df_supermarket['ingreso_diario'] = df_supermarket['unidades_vendidas_diarias'] * df_supermarket['precio_unitario']
df_supermarket['margen_ganancia'] = (df_supermarket['precio_unitario'] - df_supermarket['costo_unitario']) * df_supermarket['unidades_vendidas_diarias']
df_supermarket['margen_ganancia_porcentual'] = (df_supermarket['margen_ganancia'] / df_supermarket['ingreso_diario']).fillna(0)


df_supermarket['cambio_ventas_semanal'] = np.round(np.random.uniform(-15, 20, 1000), 2) # % de cambio
df_supermarket
# Out:
#     nombre_producto          categoria fecha_venta  unidades_vendidas_diarias  \
# 0          Manzanas  Frutas y Verduras  2025-10-22                         64
# 1         Carne Res             Carnes  2025-04-14                        128
# 2          Galletas          Panadería  2025-01-14                        180
# 3           Bananas  Frutas y Verduras  2025-10-15                        167
# 4             Pollo             Carnes  2025-06-28                        123
# ..              ...                ...         ...                        ...
# 995      Pan Blanco          Panadería  2025-12-24                         49
# 996         Lechuga  Frutas y Verduras  2025-01-05                        170
# 997           Yogur            Lácteos  2025-03-27                        138
# 998         Bananas  Frutas y Verduras  2025-06-24                         17
# 999         Bananas  Frutas y Verduras  2025-10-17                        110
#
# ...

# %%
df_supermarket.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   nombre_producto             1000 non-null   object
#  1   categoria                   1000 non-null   object
#  2   fecha_venta                 1000 non-null   datetime64[ns]
#  3   unidades_vendidas_diarias   1000 non-null   int64
#  4   precio_unitario             1000 non-null   float64
#  5   costo_unitario              1000 non-null   float64
#  6   region                      1000 non-null   object
#  7   ingreso_diario              1000 non-null   float64
#  8   margen_ganancia             1000 non-null   float64
#  9   margen_ganancia_porcentual  1000 non-null   float64
#  10  cambio_ventas_semanal       1000 non-null   float64
# dtypes: datetime64[ns](1), float64(6), int64(1), object(3)
# memory usage: 86.1+ KB

# %%
df_supermarket.describe().transpose()
# Out:
#                              count                           mean  \
# fecha_venta                   1000  2025-07-03 07:24:57.599999744
# unidades_vendidas_diarias   1000.0                        106.086
# precio_unitario             1000.0                        26.2241
# costo_unitario              1000.0                       15.26248
# ingreso_diario              1000.0                      2776.3753
# margen_ganancia             1000.0                     1160.33211
# margen_ganancia_porcentual  1000.0                      -0.137653
# cambio_ventas_semanal       1000.0                        2.39303
#
#                                             min                  25%  \
# fecha_venta                 2025-01-01 00:00:00  2025-04-02 00:00:00
# unidades_vendidas_diarias                  10.0                58.75
# precio_unitario                            1.51               13.755
# costo_unitario                             0.54                8.095
# ...

# %% [markdown]
# ### Gráficos para visualización de datos
#
# ---

# %%
# 1. Gráfico de Barras: Unidades vendidas por región
ventas_por_region = df_supermarket.groupby('region')['unidades_vendidas_diarias'].sum().reset_index()
colores=["pink", "skyblue", "orange", "yellow"]
plt.figure(figsize=(10, 6))
sb.barplot(x='region', y='unidades_vendidas_diarias', data=ventas_por_region,palette= colores, hue="region")
plt.title('Unidades Vendidas Totales por Región')
plt.xlabel('Región')
plt.ylabel('Unidades Vendidas')
plt.show()

# %%
# 2. Boxplot: Ingreso diario por categoría de producto
plt.figure(figsize=(12, 7))
sb.boxplot(x='categoria', y='ingreso_diario', data=df_supermarket, palette=colores, hue='categoria', legend=False)
plt.title('Distribución del Ingreso Diario por Categoría')
plt.xlabel('Categoría')
plt.ylabel('Ingreso Diario')
plt.xticks(rotation=45)
plt.ticklabel_format(style='plain', axis='y')
plt.show()

# %%
# 3. Gráfico de Torta: Distribución de productos por categoría

plt.figure(figsize=(8, 8))
df_supermarket['categoria'].value_counts().plot.pie(
    autopct='%.1f%%', startangle=90, colors=colores, wedgeprops=dict(width=0.3)
)
plt.title('Proporción de Productos por Categoría')
plt.ylabel('') # Eliminar el label 'count' del eje y
plt.show()

# %%
# 4. Gráfico de Líneas: Ingreso bruto diario a lo largo del tiempo
# Agrupamos por fecha para obtener el ingreso bruto diario total
ingreso_por_fecha = df_supermarket.groupby('fecha_venta')['ingreso_diario'].sum().reset_index()

plt.figure(figsize=(15, 7))
sb.lineplot(x='fecha_venta', y='ingreso_diario', data=ingreso_por_fecha)
plt.title('Tendencia del Ingreso Diario a lo Largo del Tiempo')
plt.xlabel('Fecha de Venta')
plt.ylabel('Ingreso Diario Total')
plt.grid(True, linestyle='--', alpha=0.7)
plt.ticklabel_format(style='plain', axis='y')
plt.show()

# %% [markdown]
# El gráfico anterior no es visualmente claro, vamos a mejorarlo tomando en cuenta la naturaleza de la variable fecha...

# %%
# Extraer el mes y el año de la fecha de venta
df_supermarket['año_mes'] = df_supermarket['fecha_venta'].dt.to_period('M')

# Agrupar por mes y sumar el ingreso diario
ingreso_mensual_total = df_supermarket.groupby('año_mes')['ingreso_diario'].sum().reset_index()

# Convertir 'año_mes' a string para un mejor etiquetado en el eje x
ingreso_mensual_total['año_mes'] = ingreso_mensual_total['año_mes'].astype(str)

plt.figure(figsize=(18, 8))
sb.lineplot(x='año_mes', y='ingreso_diario', data=ingreso_mensual_total, color='blue')
plt.title('Tendencia Mensual del Ingreso Diario Total')
plt.xlabel('Mes y Año')
plt.ylabel('Ingreso Diario Mensual Total')
plt.grid(True, linestyle='--', alpha=0.7)
plt.xticks(rotation=45)
plt.ticklabel_format(style='plain', axis='y')
plt.tight_layout()
plt.show()

# %%
# 5. Histograma: Distribución del margen de ganancia bruto

plt.figure(figsize=(10, 6))
sb.histplot(df_supermarket['margen_ganancia'], bins=50, kde=True, color='skyblue')
plt.title('Distribución del Margen de Ganancia')
plt.xlabel('Margen de Ganancia')
plt.ylabel('Frecuencia')
plt.ticklabel_format(style='plain', axis='x')
plt.ticklabel_format(style='plain', axis='y')
plt.show()

# %%
# 6. Gráfico de Barras: Costo Total por Categoría
df_supermarket['costo_total_diario'] = df_supermarket['costo_unitario'] * df_supermarket['unidades_vendidas_diarias']

costos_por_categoria = df_supermarket.groupby('categoria')['costo_total_diario'].sum().reset_index()

plt.figure(figsize=(12, 7))
sb.barplot(x='categoria', y='costo_total_diario', data=costos_por_categoria, palette=colores, hue='categoria', legend=False)
plt.title('Costo Total por Categoría de Producto')
plt.xlabel('Categoría')
plt.ylabel('Costo Total')
plt.xticks(rotation=45)
plt.ticklabel_format(style='plain', axis='y')
plt.show()

# %%
# 7 - Gráfico de barras, productos con mayor y menor ganancia

# 8. Gráfico de Barras Horizontales: Productos con Mayor y Menor Beneficio
productos_beneficio = df_supermarket.groupby('nombre_producto')['margen_ganancia'].sum().reset_index()

# Top 5 productos con mayor beneficio
top_5_beneficio = productos_beneficio.nlargest(5, 'margen_ganancia').copy()
top_5_beneficio['Tipo_Beneficio'] = 'Mayor Beneficio'

# Top 5 productos con menor beneficio
bottom_5_beneficio = productos_beneficio.nsmallest(5, 'margen_ganancia').copy()
bottom_5_beneficio['Tipo_Beneficio'] = 'Menor Beneficio'

# Combinar ambos para la visualización
productos_interes = pd.concat([top_5_beneficio, bottom_5_beneficio])

plt.figure(figsize=(12, 8))
sb.barplot(x='margen_ganancia', y='nombre_producto', hue='Tipo_Beneficio', data=productos_interes, palette={'Mayor Beneficio': 'green', 'Menor Beneficio': 'red'})
plt.title('Productos con Mayor y Menor Margen de Ganancia')
plt.xlabel('Margen de Ganancia')
plt.ylabel('Nombre del Producto')
plt.ticklabel_format(style='plain', axis='x')
plt.legend(title='Tipo de Beneficio')
plt.show()

# %%
productos_interes
# Out:
#    nombre_producto  margen_ganancia   Tipo_Beneficio
# 9            Queso        139386.09  Mayor Beneficio
# 4          Lechuga        135994.65  Mayor Beneficio
# 8            Pollo        122246.96  Mayor Beneficio
# 6       Pan Blanco        109431.13  Mayor Beneficio
# 3            Leche        100586.49  Mayor Beneficio
# 5         Manzanas         85099.30  Menor Beneficio
# 7          Pescado         91153.27  Menor Beneficio
# 1        Carne Res         91597.31  Menor Beneficio
# 0          Bananas         91886.12  Menor Beneficio
# 10           Yogur         93429.57  Menor Beneficio

# %%
# 8 - Unidades vendidas a lo largo del tiempo
ventas_por_categoria_fecha = df_supermarket.groupby(['fecha_venta', 'categoria'])['unidades_vendidas_diarias'].sum().reset_index()

plt.figure(figsize=(10, 8))
sb.lineplot(x='fecha_venta', y='unidades_vendidas_diarias', hue='categoria', data=ventas_por_categoria_fecha, palette='tab10')
plt.title('Serie de Unidades Vendidas por Categoría a lo Largo del Tiempo')
plt.xlabel('Fecha de Venta')
plt.ylabel('Unidades Vendidas Diarias')
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(title='Categoría')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Mejoremos el gráfico para que sea entendible y trasmita información:

# %%
# Extraer el mes y el año de la fecha de venta
ventas_por_categoria_fecha['año_mes'] = ventas_por_categoria_fecha['fecha_venta'].dt.to_period('M')

# Agrupar por mes y categoría y sumar las unidades vendidas
ventas_mensuales_por_categoria = ventas_por_categoria_fecha.groupby(['año_mes', 'categoria'])['unidades_vendidas_diarias'].sum().reset_index()

# Convertir 'año_mes' a string para un mejor etiquetado en el eje x
ventas_mensuales_por_categoria['año_mes'] = ventas_mensuales_por_categoria['año_mes'].astype(str)

plt.figure(figsize=(18, 8))
sb.lineplot(x='año_mes', y='unidades_vendidas_diarias', hue='categoria', data=ventas_mensuales_por_categoria, palette='tab10')
plt.title('Tendencia Mensual de Unidades Vendidas por Categoría')
plt.xlabel('Mes y Año')
plt.ylabel('Unidades Vendidas Mensuales')
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(title='Categoría')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# 9 - Tendencia Mensual de Margen de Ganancia Total
# Extraer el mes y el año de la fecha de venta
df_supermarket['año_mes'] = df_supermarket['fecha_venta'].dt.to_period('M')

# Agrupar por mes y sumar el margen de ganancia bruto
margen_mensual_total = df_supermarket.groupby('año_mes')['margen_ganancia'].sum().reset_index()

# Convertir 'año_mes' a string para un mejor etiquetado en el eje x
margen_mensual_total['año_mes'] = margen_mensual_total['año_mes'].astype(str)

plt.figure(figsize=(18, 8))
sb.lineplot(x='año_mes', y='margen_ganancia', data=margen_mensual_total, color='purple')
plt.title('Tendencia Mensual del Margen de Ganancia')
plt.xlabel('Mes y Año')
plt.ylabel('Margen de Ganancia Mensual')
plt.grid(True, linestyle='--', alpha=0.7)
plt.xticks(rotation=45)
plt.ticklabel_format(style='plain', axis='y')
plt.tight_layout()
plt.show()

# %%
#10 - Tendencia Mensual de Margen de Ganancia por Categoría
# Agrupar por mes y categoría y sumar el margen de ganancia
margen_mensual_por_categoria = df_supermarket.groupby(['año_mes', 'categoria'])['margen_ganancia'].sum().reset_index()

# Convertir 'año_mes' a string para un mejor etiquetado en el eje x
margen_mensual_por_categoria['año_mes'] = margen_mensual_por_categoria['año_mes'].astype(str)

plt.figure(figsize=(18, 8))
sb.lineplot(x='año_mes', y='margen_ganancia', hue='categoria', data=margen_mensual_por_categoria, palette='tab10')
plt.title('Tendencia Mensual del Margen de Ganancia por Categoría')
plt.xlabel('Mes y Año')
plt.ylabel('Margen de Ganancia Mensual')
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(title='Categoría')
plt.xticks(rotation=45)
plt.ticklabel_format(style='plain', axis='y')
plt.tight_layout()
plt.show()

# %%
# 11 - Boxplot Comparativo: Distribución del Margen de Ganancia por Categoría
plt.figure(figsize=(12, 7))
sb.boxplot(x='categoria', y='margen_ganancia', data=df_supermarket, palette=colores, hue='categoria', legend=False)
plt.title('Distribución del Margen de Ganancia por Categoría de Producto')
plt.xlabel('Categoría')
plt.ylabel('Margen de Ganancia')
plt.xticks(rotation=45)
plt.ticklabel_format(style='plain', axis='y')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# ✅ Actividad
#
# ---
# 1- Elija un archivo de datos e importelo en una notebook
#
# 2- Realice una exploración inicial y evalue parametros estadísticos de las variables cuantitativas.
#
# 3- Realice operaciones con los atributos para crear nuevos atributos.
#
# 4- Seleccione al menos 2 variables cualitativas y 2 cuantitativas para realizar visualizaciones mediante gráficos estudiados.
#
# 5- Obtenga conclusiones del análisis realizado.
